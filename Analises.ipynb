# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('USP.txt', delimiter=';', index_col=False)

df
# Out:
#                                        Nome Unid/Orgão  \
# 0                          Abel Elias Rahal    PUSP-RP
# 1                            Abel Lavorenti      ESALQ
# 2                 Abelardo Cecilio de Souza       FMVZ
# 3                           Abib Salim Cury       FORP
# 4             Abidias Lourenco de Alcantara        FCF
# 5       Abigail Barreto de Souza Simphronio        SAS
# 6                 Abigail Cardoso Goncalves        SAS
# 7                    Abigail Farias da Mota        ECA
# 8        Abigail Lais de Barros Bartholomeu         IB
# 9                            Abilio Antonio       FMRP
# 10               Abílio César Neves Tavares      FFLCH
# 11             Abinadabe Dornela dos Santos     EEFERP
# 12                 Abiude Ferreira da Silva         MP
# 13                   Ablicio Pires dos Reis         IF
# 14             Abner Cardoso Rodrigues Neto        IME
# 15                            Abner Gosmini        FOB
# ...

# %%
df['Salário Mensal'] = pd.to_numeric(df['Salário Mensal'].str.replace(',',''), errors='coerce')/100

df.sort_values(by='Salário Mensal', ascending=False)
# Out:
#                                     Nome Unid/Orgão  \
# 2898            Arrigo Leonardo Angelini         IP
# 22482                Sergio de Iudicibus        FEA
# 3264                        Boris Fausto       RUSP
# 405                 Affonso Renato Meira         FM
# 2543                     Antonio Morales        FEA
# 23131       Sonia Apparecida de Siqueira      FFLCH
# 16901       Maria Sylvia Carvalho Franco      FFLCH
# 12083        Jose Moacyr Vianna Coutinho       RUSP
# 11547                       Jose Barbosa         FO
# 17275                  Mario Demar Perez        ICB
# 9123                     Giorgio Moscati         IF
# 9348      Guilherme da Costa Pinto Filho       RUSP
# 210                   Adolpho Jose Melfi      ESALQ
# 18556                       Nelson Villa       RUSP
# 11681           Jose Cavalcante de Souza      FFLCH
# 22036        Ruy Cézar do Espírito Santo       RUSP
# 24454         Vera Lucia Machado D Avila       RUSP
# ...

# %%
df2 = pd.read_csv('Unidade.csv', index_col=False)

df2
# Out:
#                                         Tabela 7.02 -   \
# 0                                                  NaN
# 1                                                  NaN
# 2                                              Unidade
# 3    A - Ensino e Pesquisa                         ...
# 4    EACH                                          ...
# 5    ECA                                           ...
# 6    EE                                            ...
# 7    EEFE                                          ...
# 8    EEFERP                                        ...
# 9    EEL                                           ...
# 10   EERP                                          ...
# 11   EESC                                          ...
# 12   EP                                            ...
# 13   ESALQ                                         ...
# 14   FAU                                           ...
# 15   FCF                                           ...
# ...
